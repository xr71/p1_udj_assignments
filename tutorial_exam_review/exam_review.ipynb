# %%
import math
import pandas as pd 
import numpy as np

# %% [markdown]
# Durbin-Watson test
#
# data:  final.model
# DW = 2.222, p-value = 0.6875
# alternative hypothesis: true autocorrelation is greater than 0

# %% [markdown]
# Durbin Watson is a two tailed test, we can only reject the NULL HYPOTHESIS at the end of the tails

# %% [markdown]
# H0 = errors are random
#
# HA = errors are autocorrelated

# %%
# 2.69 to 4 is C rejection region
# less than 1.31 is C rejection region

# %%
# vary by degrees of freedom in the regression equation

# %%
# redraw the residual trend, will get points for this

# %%
# errors should be normally distributed with mean 0 -- should plot residual errors on normal histogram

# %%
# autocorrelation
  ## non linear
  ## missing an important independent variable

# try a transformation 
  ## because of non-linearity
  ## do not need to specify which transformation

# %%
# look for number of observations in each interval, make sure that there is sufficient data, usually non-normal due to small sample size

# %%
# residual vs predicted
# measure homo or hetero skedascity

# draw the trend and roughly explain the trend, justify it one way or another

# %%
# coming in as a constant rate, it is Poisson
# if there is a SAMPLE n, then it is binomial
